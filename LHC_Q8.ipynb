# %%
#importing basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/"MyDrive/"
# Out:
# /content/drive/MyDrive

# %%
#Import the libraries
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/DatasetLHC/Arjun_Assignment_data-20220427T165022Z-002.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()

#/content/drive/MyDrive/Colab Notebooks/DatasetLHC/Arjun_Assignment_data-20220427T165022Z-002.zip

# %%
#Import the libraries
import zipfile
import os

zip_ref = zipfile.ZipFile('/tmp/Arjun_Assignment_data/dataset-20210607T020316Z-002.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp/dataset2') #Extracts the files into the /tmp folder
zip_ref.close()

#/content/drive/MyDrive/Colab Notebooks/DatasetLHC/Arjun_Assignment_data-20220427T165022Z-002.zip
#/tmp/Arjun_Assignment_data/dataset-20210607T020316Z-002.zip
#/tmp/Arjun_Assignment_data/dataset-20210607T020316Z-003.zip

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DatasetLHC/dataset/postLinks.csv')

#/content/drive/MyDrive/Colab Notebooks/synchronousmachine.csv
#/content/drive/MyDrive/Colab Notebooks/DatasetLHC/dataset/postLinks.csv

#/tmp/Arjun_Assignment_data/dataset-20210607T020316Z-001.zip
#/tmp/dataset/postLinks.csv

# %%
dataset1 = pd.read_csv('/tmp/dataset2/dataset/post_history.csv')

#/content/drive/MyDrive/Colab Notebooks/synchronousmachine.csv
#/content/drive/MyDrive/Colab Notebooks/DatasetLHC/dataset/postLinks.csv

#/tmp/Arjun_Assignment_data/dataset-20210607T020316Z-001.zip
#/tmp/dataset/postLinks.csv

# %%
dataset2 = pd.read_csv('/tmp/dataset2/dataset/users.csv')

#/content/drive/MyDrive/Colab Notebooks/synchronousmachine.csv
#/content/drive/MyDrive/Colab Notebooks/DatasetLHC/dataset/postLinks.csv

#/tmp/Arjun_Assignment_data/dataset-20210607T020316Z-001.zip
#/tmp/dataset/postLinks.csv

# %%
dataset
# Out:
#          Unnamed: 0          id            creation_date   post_id  \
# 0                 0          19  2010-04-26T02:59:48.130       109
# 1                 1          37  2010-04-26T02:59:48.600      1970
# 2                 2          42  2010-04-26T02:59:48.647      2154
# 3                 3          48  2010-04-26T02:59:48.740      2483
# 4                 4          52  2010-04-26T02:59:48.757      2572
# ...             ...         ...                      ...       ...
# 5292619     5292619  1624278139  2018-09-02T08:09:41.520  52133002
# 5292620     5292620  1624278147  2018-09-02T08:10:50.820  52134991
# 5292621     5292621  1624278315  2018-09-02T08:14:26.470  52135049
# 5292622     5292622  1624278337  2018-09-02T08:15:36.387  52135007
# 5292623     5292623  1624278449  2018-09-02T08:17:32.137  52135049
#
#          related_post_id  link_type_id
# 0                  32412             1
# 1                 617600             1
# 2                2451138             1
# ...

# %%
dataset1
# Out:
#          Unnamed: 0         id  ph_type_id   post_id  \
# 0                 0         12           1        17
# 1                 1         13           3        17
# 2                 2         14           2        17
# 3                 3        219           1       123
# 4                 4        220           3       123
# ...             ...        ...         ...       ...
# 3640996     3640996  180953899           1  52134558
# 3640997     3640997  180953900           3  52134558
# 3640998     3640998  180953916           5  52134558
# 3640999     3640999  180954028          10  52134558
# 3641000     3641000  180954083           5  52134558
#
#                                 revision_guid            creation_date  \
# 0        0421fb42-a29a-4cb2-84ba-a828725410f8  2008-08-01T05:09:55.993
# 1        0421fb42-a29a-4cb2-84ba-a828725410f8  2008-08-01T05:09:55.993
# 2        0421fb42-a29a-4cb2-84ba-a828725410f8  2008-08-01T05:09:55.993
# ...

# %%
dataset2
# Out:
#          Unnamed: 0        id  reputation            creation_date  \
# 0                 0        -1           1  2008-07-31T00:00:00.000
# 1                 1         1       44300  2008-07-31T14:22:31.287
# 2                 2         2        3491  2008-07-31T14:22:31.287
# 3                 3         3       13418  2008-07-31T14:22:31.287
# 4                 4         4       28768  2008-07-31T14:22:31.317
# ...             ...       ...         ...                      ...
# 9321919     9321919  10305605           1  2018-09-02T05:43:27.763
# 9321920     9321920  10305606           1  2018-09-02T05:43:49.343
# 9321921     9321921  10305607           1  2018-09-02T05:43:57.907
# 9321922     9321922  10305608           1  2018-09-02T05:44:02.417
# 9321923     9321923  10305609           1  2018-09-02T05:44:16.507
#
#              display_name   views  upvotes  downvotes  account_id
# 0               Community     649   274835     980920          -1
# ...

# %%
col = list(dataset.columns.values)
print(col)
# Out:
# ['Unnamed: 0', 'id', 'creation_date', 'post_id', 'related_post_id', 'link_type_id']

# %%
df1 = pd.DataFrame()

# %%
df1['post_id'] = dataset['post_id']

# %%
df1['link_type_id'] = dataset['link_type_id']

# %%
col1 = list(dataset1.columns.values)
print(col1)
# Out:
# ['Unnamed: 0', 'id', 'ph_type_id', 'post_id', 'revision_guid', 'creation_date', 'user_id', 'user_display_name', 'comment', 'text']

# %%
df2 = pd.DataFrame()

# %%
df2['post_id'] = dataset1['post_id']

# %%
df2['user_id'] = dataset1['user_id']

# %%
col2 = list(dataset2.columns.values)
print(col2)
# Out:
# ['Unnamed: 0', 'id', 'reputation', 'creation_date', 'display_name', 'views', 'upvotes', 'downvotes', 'account_id']

# %%
df3 = pd.DataFrame()

# %%
df3['user_id'] = dataset2['id']

# %%
df3['reputation'] = dataset2['reputation']

# %%
df1
# Out:
#           post_id  link_type_id
# 0             109             1
# 1            1970             1
# 2            2154             1
# 3            2483             1
# 4            2572             1
# ...           ...           ...
# 5292619  52133002             1
# 5292620  52134991             1
# 5292621  52135049             1
# 5292622  52135007             1
# 5292623  52135049             1
#
# [5292624 rows x 2 columns]

# %%
df2
# Out:
#           post_id   user_id
# 0              17         2
# 1              17         2
# 2              17         2
# 3             123        78
# 4             123        78
# ...           ...       ...
# 3640996  52134558  10305684
# 3640997  52134558  10305684
# 3640998  52134558  10305684
# 3640999  52134558   9515207
# 3641000  52134558   3589092
#
# [3641001 rows x 2 columns]

# %%
df3
# Out:
#           user_id  reputation
# 0              -1           1
# 1               1       44300
# 2               2        3491
# 3               3       13418
# 4               4       28768
# ...           ...         ...
# 9321919  10305605           1
# 9321920  10305606           1
# 9321921  10305607           1
# 9321922  10305608           1
# 9321923  10305609           1
#
# [9321924 rows x 2 columns]

# %%
#del df3['id']

# %%
df4 = pd.merge(df1,df2,on="post_id")
df4
# Out:
#           post_id  link_type_id  user_id
# 0            2483             1       91
# 1            2483             1       91
# 2            2483             1       91
# 3            2483             1       -1
# 4            2483             1   105971
# ...           ...           ...      ...
# 6111159  52134495             1  9992447
# 6111160  52134495             3  9992447
# 6111161  52134495             3  9992447
# 6111162  52134495             3  9992447
# 6111163  52134495             3  9992447
#
# [6111164 rows x 3 columns]

# %%
df5 = pd.merge(df4,df3,on="user_id")
df5
# Out:
#           post_id  link_type_id   user_id  reputation
# 0            2483             1        91      113539
# 1            2483             1        91      113539
# 2            2483             1        91      113539
# 3            2483             3        91      113539
# 4            2483             3        91      113539
# ...           ...           ...       ...         ...
# 5883635  52134533             1  10301563           1
# 5883636  52134533             1  10301563           1
# 5883637  52134533             3  10301563           1
# 5883638  52134533             3  10301563           1
# 5883639  52134533             3  10301563           1
#
# [5883640 rows x 4 columns]

# %%
df5['link_type_id'] = df5['link_type_id'].astype('int')

# %%
df6 = pd.DataFrame()

# %%
l = []
for k in range(len(df5)):
  if(df5['link_type_id'][k] == 3):
    l.append(df5['reputation'][k])

# %%
l

# %%
unique_rep = []
for x in l:
    if x not in unique_rep:
        unique_rep.append(x)
print(unique_rep)
# Out:
# [113539, 1, 28408, 41167, 7773, 10711, 31078, 59441, 11021, 3575, 15326, 490655, 5904, 49742, 5594, 52015, 280958, 3825, 44422, 31835, 8775, 37267, 144, 41960, 30494, 331228, 164698, 64508, 26483, 159098, 44840, 3018, 4078, 14807, 65933, 12940, 2294, 15112, 14878, 112845, 99755, 87802, 60959, 250048, 34329, 20964, 76387, 3078, 11771, 131228, 230260, 11206, 42357, 3496, 8230, 44300, 51385, 13440, 2834, 11540, 41194, 13138, 45267, 13418, 11164, 25035, 109358, 40419, 359545, 29590, 682, 214977, 20670, 95308, 54145, 4390, 108550, 8715, 48867, 183110, 143362, 34553, 14949, 49559, 9949, 4295, 103947, 517, 23307, 20737, 197893, 46750, 34104, 8921, 3359, 8864, 36602, 25858, 5173, 323, 33285, 1229, 23250, 3616, 33026, 23363, 76293, 38139, 15325, 84784, 1324, 7148, 86119, 160110, 50443, 1196, 58734, 34107, 15084, 50537, 31455, 66973, 15775, 9467, 6593, 58941, 62701, 64546, 4083, 24735, 33179, 5910, 35630, 44407, 18312, 12187, 125409, 4162, 7330, 119027, 83233, 818687, 16342, 22303, 296963, 716
# ...

# %%
print("Total No. of Unique_tags:",(len(unique_rep)))
# Out:
# Total No. of Unique_tags: 17629

# %%
#Q3
from collections import Counter
input = l
c = Counter( input )

print( c.items() )
# Out:
# dict_items([(113539, 20), (1, 466596), (28408, 293), (41167, 9), (7773, 27), (10711, 10), (31078, 5), (59441, 130), (11021, 22), (3575, 21), (15326, 1), (490655, 227), (5904, 33), (49742, 27), (5594, 12), (52015, 7), (280958, 3811), (3825, 478), (44422, 37), (31835, 18), (8775, 6), (37267, 2), (144, 1448), (41960, 1), (30494, 49), (331228, 427), (164698, 35), (64508, 76), (26483, 2), (159098, 82), (44840, 2389), (3018, 46), (4078, 30), (14807, 81), (65933, 3), (12940, 2176), (2294, 64), (15112, 89), (14878, 14), (112845, 67), (99755, 74), (87802, 29), (60959, 4), (250048, 297), (34329, 69), (20964, 32), (76387, 545), (3078, 68), (11771, 1), (131228, 362), (230260, 276), (11206, 51), (42357, 613), (3496, 46), (8230, 20), (44300, 1005), (51385, 615), (13440, 3), (2834, 28), (11540, 22), (41194, 337), (13138, 30), (45267, 4), (13418, 62), (11164, 3), (25035, 19), (109358, 1334), (40419, 126), (359545, 26), (29590, 3), (682, 246), (214977, 50), (20670, 14), (95308, 892), (54145, 8), (439
# ...

# %%
d = dict(c)
#mylist=tags
#[ (c,mylist.count(c)) for c in set(mylist) ]

# %%
d

# %%
d
new_d = {}
for k, v in d.items():
    new_d[v] = k

# %%
new_d
# Out:
# {1: 4798,
#  2: 9950,
#  3: 12219,
#  4: 106648,
#  5: 4567,
#  6: 15345,
#  7: 8405,
#  8: 7963,
#  9: 13263,
#  10: 8603,
#  11: 4709,
#  12: 21115,
#  13: 4565,
#  14: 63184,
#  15: 17631,
#  16: 10800,
#  17: 10119,
#  18: 10761,
#  19: 44243,
#  20: 16809,
#  21: 13211,
#  22: 40798,
#  23: 6502,
#  24: 11945,
#  25: 15440,
#  26: 9624,
#  27: 4832,
#  28: 14128,
#  29: 12542,
#  30: 9015,
#  31: 13051,
#  32: 31591,
#  33: 35951,
#  34: 14036,
#  35: 23275,
#  36: 20694,
#  37: 10651,
#  38: 10550,
#  39: 21220,
#  40: 30464,
#  41: 6868,
#  42: 12810,
#  43: 8472,
#  44: 6973,
#  45: 6756,
#  46: 33100,
#  47: 8194,
#  48: 19190,
#  49: 30161,
#  50: 32279,
#  51: 16921,
#  52: 24737,
#  53: 28333,
#  54: 22342,
#  55: 29156,
#  56: 22302,
#  57: 18048,
#  58: 117328,
#  59: 11537,
#  60: 11468,
#  61: 113330,
#  62: 52199,
#  63: 19777,
#  64: 16544,
#  65: 67350,
#  66: 17727,
#  67: 49655,
#  68: 9457,
#  69: 43550,
#  70: 9238,
#  71: 29714,
#  72: 5345,
#  73: 16056,
# ...

# %%
import operator
sorted_d = dict( sorted(d.items(), key=operator.itemgetter(1),reverse=True))

# %%
sorted_d

# %%
import operator
sorted_d1 = dict( sorted(new_d.items(), key=operator.itemgetter(1),reverse=False))

# %%
sorted_d1

# %%
import collections
od = collections.OrderedDict(sorted(d.items(),reverse=True))

# %%
od

# %%
df1 = pd.DataFrame([od])

# %%
df1 = df1.melt( 
        var_name="Reputation", 
        value_name="Dupli_Que_Ask")

# %%
df1
# Out:
#        Reputation  Dupli_Que_Ask
# 0         1047863            529
# 1          818687           7547
# 2          814505             27
# 3          800368             35
# 4          768855            516
# ...           ...            ...
# 17624           5           8336
# 17625           4          16674
# 17626           3          31209
# 17627           2           5089
# 17628           1         466596
#
# [17629 rows x 2 columns]

# %%
plt.figure(figsize=(25, 7))
plt.plot(df1['Reputation'],df1['Dupli_Que_Ask'])
plt.xlabel("Reputation")
plt.ylabel("No. Of Duplicate Questions Asked")
plt.title("Duplicate Questions asked by different reputated users")

#labels = df_percent['Tags']
#plt.xticks(x, labels, rotation ='vertical')

plt.show()

# %%
x = []
for i in range(len(df1)):
  x.append(df1['Reputation'][i])

# %%
x

# %%
y = []
for i in range(len(df1)):
  y.append(df1['Dupli_Que_Ask'][i])

# %%
y

# %%
plt.figure(figsize=(25, 7))
plt.bar(x,y, color ='maroon',
        width = 0.4)
plt.xlabel("Tags")
plt.ylabel("Duplication Percentage")
plt.title("Duplication Percentage for top20 tags")
#plt.xticks(x, labels, rotation ='vertical')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
 

 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(x, bins = 5)
 
# Show plot
plt.show()

# %%
df2 = df1[0:2001]

# %%
df3 = df1[2001:4000]

# %%
df4 = df1[4001:6000]

# %%
df5 = df1[6001:8000]

# %%
df6 = df1[8001:10000]

# %%
df7 = df1[10001:12000]

# %%
df8 = df1[12001:14000]

# %%
df9 = df1[14001:16000]

# %%
df10 = df1[16001:]

# %%
Total1 = df2['Dupli_Que_Ask'].sum()
Total2 = df3['Dupli_Que_Ask'].sum()
Total3 = df4['Dupli_Que_Ask'].sum()
Total4 = df5['Dupli_Que_Ask'].sum()
Total5 = df6['Dupli_Que_Ask'].sum()
Total6 = df7['Dupli_Que_Ask'].sum()
Total7 = df8['Dupli_Que_Ask'].sum()
Total8 = df9['Dupli_Que_Ask'].sum()
Total9 = df10['Dupli_Que_Ask'].sum()

# %%
range_dict = {1:Total1 , 2:Total2, 3:Total3, 4:Total4, 5:Total5, 6:Total6, 7:Total7, 8:Total8, 9:Total9}

# %%
range_dict
# Out:
# {1: 280637,
#  2: 76419,
#  3: 41989,
#  4: 43311,
#  5: 36746,
#  6: 47560,
#  7: 69648,
#  8: 138095,
#  9: 1563144}

# %%
x = list()
y = list()
for i,j in range_dict.items():
  x.append(i)
  y.append(j)
print(x)
print(y)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [280637, 76419, 41989, 43311, 36746, 47560, 69648, 138095, 1563144]

# %%
df10.tail()
# Out:
#        Reputation  Dupli_Que_Ask
# 17624           5           8336
# 17625           4          16674
# 17626           3          31209
# 17627           2           5089
# 17628           1         466596

# %%
labels = [">43550","bet 43550 to 24368 ","bet 24368 to 16009" , "between 16009 to 11179", "bet 11179 to 8077 ","bet 8077 to 5690", "bet 5609 to 3633","bet 3633 to 1630","bet 1630 to 1"]

# %%
plt.figure(figsize=(25, 7))
plt.bar(x, y, color ='maroon',
        width = 0.4)
plt.xlabel("Reputation")
plt.ylabel("No. Of Duplicate Questions Asked")
plt.title("Duplicate Questions Asked by Corresponding Reputated Person")
plt.xticks(x, labels, rotation ='vertical')
plt.show()
